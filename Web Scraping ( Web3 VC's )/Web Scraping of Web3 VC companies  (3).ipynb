# %% [markdown]
# # Web Scraping.
# scraping information about Web3 VC companies from https://crypto-fundraising.info/investors/

# %% [markdown]
# # Importing Necessary Libraries
# - requests: sends HTTP requests to the target website and receives the webpage content.
# - BeautifulSoup: parses the webpage, navigating and extracting specific elements from the HTML.
# - pandas: to structure and manage the data in a DataFrame, making it easy to analyze and export.
# - time: to create delays between requests, to avoid overloading the server

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# - Setting Up the Target URL
# - Sending an HTTP Request to Fetch Web Page Content
# - Parsing HTML Content with BeautifulSoup

# %%
url = "https://crypto-fundraising.info/investors/"
    
page = requests.get(url)
    
soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# - Inspecting the Web Page

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="user-scalable=no, initial-scale=1, maximum-scale=1, minimum-scale=1, width=device-width, height=device-height, target-densitydpi=device-dpi" name="viewport">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon">
#     <link as="image" href="https://crypto-fundraising.info/wp-content/themes/ico/img/cf-logo.svg" rel="preload"/>
#     <link as="image" href="https://crypto-fundraising.info/wp-content/themes/ico/img/sort-all.png" rel="preload"/>
#     <link as="image" href="https://crypto-fundraising.info/wp-content/themes/ico/img/sort-bottom.png" rel="preload"/>
#     <link as="image" href="https://crypto-fundraising.info/wp-content/themes/ico/img/sort-top.png" rel="preload"/>
#     <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_93b19b5612357300a063ffc1fa70f84f.css" media="all" rel="stylesheet" type="text/css">
#      <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_58be32b1de9286357161bd2936231a4f.css" media="all" rel="stylesheet" type="text/css">
#       <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_fde6f078ecfb85c719a713cd1911f12e.css" media="all" rel="stylesheet" type="text/css">
#        <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_2c61fe847e6ddbb9426818441f0a006b.css" media="all" rel="stylesheet" type="text/css">
#         <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_43a1c4168451a9f9b4ba3970b77d70ca.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_55e1d560821b4a4b141b0ab6cbb74d26.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_1afa6363fa8da39c8407c2605cdade24.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_6a49557212c696aa2b5d943be19d1aec.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_7a896072d9ed3da8e1c32d9aa0fe7843.css" media="all" rel="stylesheet" type="text/css"/>
#         <link href="https://crypto-fundraising.info/wp-content/cache/breeze-minification/css/breeze_36c0d6bd5008b7294e1d89885f991b1c.css" media="all" rel="stylesheet" type="text/css"/>
#         <title>
#          Investors | CRYPTO fundraising
#         </title>
#         <meta content="Crypto-Fundraising is a leading blockchain-focused funding database. It tracks every crypto fundraising round from pre-seed to Series C. The platform provides access to historical data, profiles of the investment institutions and early-stage startups." name="description"/>
#         <meta content="Investors | CRYPTO fundraising" property="og:title">
#          <link href="https://crypto-fundraising.info/investors/" rel="canonical"/>
#          <meta content="https://crypto-fundraising.info/investors/" property="og:url"/>
#          <meta content="Crypto-Fundraising is a leading blockchain-focused funding database. It tracks every crypto fundraising round from pre-seed to Series C. The platform provides access to historical data, profiles of the investment institutions and early-stage startups." property="og:description"/>
#          <meta content="en_US" property="og:locale"/>
#          <meta content="website" property="og:type"/>
#          <meta content="CRYPTO fundraising" property="og:site_name"/>
#          <meta content="https://crypto-fundraising.info/wp-content/themes/ico/img/sharing.png" property="og:image"/>
#          <meta content="summary_large_image" name="twitter:card"/>
#          <meta content="@Crypto_Dealflow" name="twitter:site"/>
#          <meta content="@Crypto_Dealflow" name="twitter:creator"/>
#          <meta content="Investors" name="twitter:title"/>
#          <meta content="Crypto-Fundraising is a leading blockchain-focused funding database. It tracks every crypto fundraising round from pre-seed to Series C. The platform provides access to historical data, profiles of the investment institutions and early-stage startups." name="twitter:description"/>
#          <meta content="https://crypto-fundraising.info/wp-content/themes/ico/img/sharing.png" name="twitter:image"/>
#          <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#           <link href="https://crypto-fundraising.info/feed/" rel="alternate" title="CRYPTO fundraising » Feed" type="application/rss+xml"/>
#           <link href="https://crypto-fundraising.info/comments/feed/" rel="alternate" title="CRYPTO fundraising » Comments Feed" type="application/rss+xml"/>
#           <style id="classic-theme-styles-inline-css">
#            /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
#           </style>
#           <style id="global-styles-inline-css">
#            :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flex{display: flex;}.is-layout-flex{flex-wrap: wrap;align-items: center;}.is-layout-flex > :is(*, div){margin: 0;}body .is-layout-grid{display: grid;}.is-layout-grid > :is(*, div){margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}:where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--lu ...
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
#           </style>
#           <script id="jquery-core-js" src="https://crypto-fundraising.info/wp-includes/js/jquery/jquery.min.js?ver=3.7.1">
#           </script>
#           <script id="jquery-migrate-js" src="https://crypto-fundraising.info/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.4.1">
#           </script>
#           <script id="wp-dom-ready-js" src="https://crypto-fundraising.info/wp-includes/js/dist/dom-ready.min.js?ver=f77871ff7694fffea381">
#           </script>
#           <script id="wpautoterms_base-js" src="https://crypto-fundraising.info/wp-content/plugins/auto-terms-of-service-and-privacy-policy/js/base.js?ver=2.5.1">
#           </script>
#           <script id="adrotate-clicktracker-js-extra">
#            var click_object = {"ajax_url":"https:\/\/crypto-fundraising.info\/wp-admin\/admin-ajax.php"};
#           </script>
#           <script id="adrotate-clicktracker-js" src="https://crypto-fundraising.info/wp-content/plugins/adrotate-pro/library/clicker.js">
#           </script>
#           <link href="https://crypto-fundraising.info/wp-json/" rel="https://api.w.org/"/>
#           <link href="https://crypto-fundraising.info/wp-json/wp/v2/pages/3415" rel="alternate" title="JSON" type="application/json"/>
#           <link href="https://crypto-fundraising.info/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#           <link href="https://crypto-fundraising.info/?p=3415" rel="shortlink"/>
#           <link href="https://crypto-fundraising.info/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fcrypto-fundraising.info%2Finvestors%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
#           <link href="https://crypto-fundraising.info/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fcrypto-fundraising.info%2Finvestors%2F&amp;format=xml" rel="alternate" title="oEmbed (XML)" type="text/xml+oembed"/>
#           <style media="screen" type="text/css">
#            .g { margin:0px; padding:0px; overflow:hidden; line-height:1; zoom:1; }
# 	.g img { height:auto; }
# 	.g-col { position:relative; float:left; }
# 	.g-col:first-child { margin-left: 0; }
# 	.g-col:last-child { margin-right: 0; }
# 	.woocommerce-page .g, .bbpress-wrapper .g { margin: 20px auto; clear:both; }
# 	.g-7 {  margin: 0 auto; }
# 	@media only screen and (max-width: 480px) {
# 		.g-col, .g-dyn, .g-single { width:100%; margin-left:0; margin-right:0; }
# 		.woocommerce-page .g, .bbpress-wrapper .g { margin: 10px auto; }
# 	}
#           </style>
#           <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-13WSK8W0L4">
#           </script>
#           <script>
#            window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-13WSK8W0L4');
#           </script>
#           <script>
#            (function(c,l,a,r,i,t,y){
#     c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#     t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#     y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "jy1g2x2btb");
#           </script>
#          </meta>
#         </meta>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="page-template-default page page-id-3415 wp-featherlight-captions">
#   <div class="site" id="page">
#    <div class="disclaimer-spacer">
#     <div class="disclaimer agreed">
#      <div class="wrapper-min">
#       <span>
#        <img alt="info" height="20" src="https://crypto-fundraising.info/wp-content/themes/ico/img/ic_info.svg" width="20"/>
#        <b>
#         Disclaimer:
#        </b>
#        the information provided by CRYPTO fundraising team should not be considered as investment advice
# or an invitation to trade.
#       </span>
#       <span class="agree-link">
#        Agree and close
#       </span>
#      </div>
#     </div>
#    </div>
#    <header class="header-outer lgbg">
#     <div class="header-inner header-wrapper">
#      <div class="logoandsearch">
#       <a href="https://crypto-fundraising.info/" rel="home">
#        <img alt="logo" class="logo-full" height="57" src="https://crypto-fundraising.info/wp-content/themes/ico/img/cf-logo.svg" width="231"/>
#        <img alt="logo" class="logo-compact" height="57" src="https://crypto-fundraising.info/wp-content/themes/ico/img/cf-logo2.svg" width="178"/>
#       </a>
#       <div class="searchform acompwrap" data-type="projectsandfunds">
#        <input class="custom-acomplete" onblur="this.placeholder='Search projects or funds'" onfocus="this.placeholder=''" placeholder="Search projects or funds" type="text"/>
#        <ul class="acomplist">
#        </ul>
#       </div>
#      </div>
#      <nav class="header-navigation main-navigation" id="site-navigation">
#       <div class="menu-menu-1-container">
#        <ul class="menu" id="primary-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3427" id="menu-item-3427">
#          <a href="https://crypto-fundraising.info/deal-flow/">
#           VC Deal flow
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-3415 current_page_item menu-item-3417" id="menu-item-3417">
#          <a aria-current="page" href="https://crypto-fundraising.info/investors/">
#           Investors
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-6887" id="menu-item-6887">
#          <a href="/blog">
#           News
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-59754" id="menu-item-59754">
#          <a href="https://crypto-fundraising.info/api/">
#           API
#          </a>
#         </li>
#         <li class="accountmenu menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-7626" id="menu-item-7626">
#          <a href="#">
#           My account
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7627" id="menu-item-7627">
#            <a href="https://crypto-fundraising.info/personal-deal-flow/">
#             Personal dashboard
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-7628" id="menu-item-7628">
#            <a href="https://crypto-fundraising.info/shortlist/">
#             My Favourites
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7629" id="menu-item-7629">
#            <a href="/wp-login.php?action=logout">
#             Log out
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="loginlink menu-item menu-item-type-custom menu-item-object-custom menu-item-7645" id="menu-item-7645">
#          <a href="/wp-login.php?redirect_to=https://crypto-fundraising.info/">
#           Sign in
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="menu-toggle">
#        <img alt="logo" class="mobilemenu" height="24" src="https://crypto-fundraising.info/wp-content/themes/ico/img/hamburger.svg" width="24"/>
#        <img alt="logo" class="mobilemenu-active" height="24" src="https://crypto-fundraising.info/wp-content/themes/ico/img/hamburger-active.svg" width="24"/>
#       </div>
#       <div class="clearfix">
#       </div>
#      </nav>
#     </div>
#    </header>
#    <script>
#     var homeurl = 'https://crypto-fundraising.info';
# var currentpageurl = "https://crypto-fundraising.info/investors/";
#    </script>
#    <main class="site-main funds" id="primary">
#     <div class="wrapper">
#      <div class="central-banner dt-only">
#      </div>
#      <div class="central-banner mobile">
#      </div>
#     </div>
#     <div class="wrapper title-search">
#      <div class="mobsearchbut">
#       <h1>
#        Investors
#       </h1>
#       <div class="searchtrigger mob-only">
#        Search
#       </div>
#      </div>
#      <div class="fundsearch">
#       <div class="searchfundouter acompwrap custom-acomplete-wrap" data-action="direct" data-type="funds">
#        <input class="custom-acomplete" id="searchfund" onblur="this.placeholder='Search investors'" onfocus="this.placeholder=''" placeholder="Search investors" type="text"/>
#        <ul class="acomplist">
#        </ul>
#        <div id="searchfundbutton">
#        </div>
#       </div>
#      </div>
#      <div class="mostactivefilter">
#       <span class="rangelabel">
#        Show most active funds:
#       </span>
#       <span class="rangeselector" data-range="30d">
#        30 days
#       </span>
#       |
#       <span class="rangeselector" data-range="thisyear">
#        this year
#       </span>
#       |
#       <span class="rangeselector" data-range="lastyear">
#        last year
#       </span>
#       |
#       <span class="rangeselector currentdaterange" data-range="alltime">
#        all time
#       </span>
#      </div>
#     </div>
#     <div class="wrapper-w-sidebar">
#      <div class="main-col">
#       <script>
#        var topten =  [{"post_id":"249"},{"post_id":"410"},{"post_id":"557"},{"post_id":"370"},{"post_id":"741"},{"post_id":"573"},{"post_id":"247"},{"post_id":"568"},{"post_id":"840"},{"post_id":"407"}];
#       </script>
#       <div class="hp-table dealflow-table">
#        <div class="hp-table-row hpt-header">
#         <div class="hpt-col1 htop">
#          <span>
#           #
#          </span>
#         </div>
#         <div class="hpt-col2 htop wsort">
#          <div class="sorter" data-sort="default" data-sortby="pname">
#          </div>
#          <span>
#           Fund name
#          </span>
#         </div>
#         <div class="hpt-col3 htop">
#         </div>
#         <div class="hpt-col4 htop">
#          <span>
#           Website
#          </span>
#         </div>
#         <div class="hpt-col5 htop wsort">
#          <div class="sorter" data-sort="default" data-sortby="pcount">
#          </div>
#          <span>
#           Invested projects
#          </span>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="249" data-fund_slug="coinbase-ventures">
#         <div class="hpt-col1">
#          01
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/coinbase-ventures">
#           <img alt="Coinbase Ventures" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/01/cb-ven.png"/>
#          </a>
#          <p class="mob-only">
#           Coinbase Ventures
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Coinbase Ventures
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.coinbase.com/ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://www.coinbase.com/ventures">
#           https://www.coinbase.com/ventures
#          </a>
#          <a href="https://twitter.com/cbventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/cbventures">
#           https://twitter.com/cbventures
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/coinbase-ventures">
#           <div class="pcount" data-funid="249">
#            331
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="410" data-fund_slug="animoca-brands">
#         <div class="hpt-col1">
#          02
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/animoca-brands">
#           <img alt="Animoca Brands" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Animoca-Brands.png"/>
#          </a>
#          <p class="mob-only">
#           Animoca Brands
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Animoca Brands
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.animocabrands.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.animocabrands.com/">
#           https://www.animocabrands.com/
#          </a>
#          <a href="https://twitter.com/animocabrands" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/animocabrands">
#           https://twitter.com/animocabrands
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/animoca-brands">
#           <div class="pcount" data-funid="410">
#            263
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="557" data-fund_slug="digital-currency-group">
#         <div class="hpt-col1">
#          03
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/digital-currency-group">
#           <img alt="Digital Currency Group (DCG)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Digital-Currency-Group@3x-logo.png"/>
#          </a>
#          <p class="mob-only">
#           Digital Currency Group (DCG)
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Digital Currency Group (DCG)
#         </div>
#         <div class="hpt-col4">
#          <a href="https://dcg.co/" rel="noopener noreferrer nofollow" target="_blank" title="https://dcg.co/">
#           https://dcg.co/
#          </a>
#          <a href="https://twitter.com/DCGco" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/DCGco">
#           https://twitter.com/DCGco
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/digital-currency-group">
#           <div class="pcount" data-funid="557">
#            225
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="370" data-fund_slug="a16z-crypto">
#         <div class="hpt-col1">
#          04
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/a16z-crypto">
#           <img alt="Andreessen Horowitz (a16z crypto)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/a16zcrypto_Logo.png"/>
#          </a>
#          <p class="mob-only">
#           Andreessen Horowitz (a16z crypto)
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Andreessen Horowitz (a16z crypto)
#         </div>
#         <div class="hpt-col4">
#          <a href="https://a16zcrypto.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://a16zcrypto.com/">
#           https://a16zcrypto.com/
#          </a>
#          <a href="https://twitter.com/a16zcrypto" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/a16zcrypto">
#           https://twitter.com/a16zcrypto
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/a16z-crypto">
#           <div class="pcount" data-funid="370">
#            224
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="741" data-fund_slug="ngc-ventures">
#         <div class="hpt-col1">
#          05
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/ngc-ventures">
#           <img alt="NGC Ventures (NEO Global Capital)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/Funds/NGC-Ventures.png"/>
#          </a>
#          <p class="mob-only">
#           NGC Ventures (NEO Global Capital)
#          </p>
#         </div>
#         <div class="hpt-col3">
#          NGC Ventures (NEO Global Capital)
#         </div>
#         <div class="hpt-col4">
#          <a href="https://ngc.fund/" rel="noopener noreferrer nofollow" target="_blank" title="https://ngc.fund/">
#           https://ngc.fund/
#          </a>
#          <a href="https://twitter.com/NGC_Ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/NGC_Ventures">
#           https://twitter.com/NGC_Ventures
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/ngc-ventures">
#           <div class="pcount" data-funid="741">
#            208
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="573" data-fund_slug="polychain-capital">
#         <div class="hpt-col1">
#          06
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/polychain-capital">
#           <img alt="Polychain Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/polychain.png"/>
#          </a>
#          <p class="mob-only">
#           Polychain Capital
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Polychain Capital
#         </div>
#         <div class="hpt-col4">
#          <a href="https://polychain.capital/" rel="noopener noreferrer nofollow" target="_blank" title="https://polychain.capital/">
#           https://polychain.capital/
#          </a>
#          <a href="https://twitter.com/polychain" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/polychain">
#           https://twitter.com/polychain
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/polychain-capital">
#           <div class="pcount" data-funid="573">
#            204
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="247" data-fund_slug="pantera-capital">
#         <div class="hpt-col1">
#          07
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/pantera-capital">
#           <img alt="Pantera Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/01/Pantera-capital.png"/>
#          </a>
#          <p class="mob-only">
#           Pantera Capital
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Pantera Capital
#         </div>
#         <div class="hpt-col4">
#          <a href="https://panteracapital.com/firm/" rel="noopener noreferrer nofollow" target="_blank" title="https://panteracapital.com/firm/">
#           https://panteracapital.com/firm/
#          </a>
#          <a href="https://twitter.com/PanteraCapital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/PanteraCapital">
#           https://twitter.com/PanteraCapital
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/pantera-capital">
#           <div class="pcount" data-funid="247">
#            189
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="568" data-fund_slug="hashkey-capital">
#         <div class="hpt-col1">
#          08
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/hashkey-capital">
#           <img alt="Hashkey Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/header-v3-logo-2.png"/>
#          </a>
#          <p class="mob-only">
#           Hashkey Capital
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Hashkey Capital
#         </div>
#         <div class="hpt-col4">
#          <a href="https://capital.hashkey.com/en/" rel="noopener noreferrer nofollow" target="_blank" title="https://capital.hashkey.com/en/">
#           https://capital.hashkey.com/en/
#          </a>
#          <a href="https://twitter.com/HashKey_Capital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/HashKey_Capital">
#           https://twitter.com/HashKey_Capital
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/hashkey-capital">
#           <div class="pcount" data-funid="568">
#            176
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="840" data-fund_slug="the-spartan-group">
#         <div class="hpt-col1">
#          09
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/the-spartan-group">
#           <img alt="The Spartan Group" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/600_478869280.png"/>
#          </a>
#          <p class="mob-only">
#           The Spartan Group
#          </p>
#         </div>
#         <div class="hpt-col3">
#          The Spartan Group
#         </div>
#         <div class="hpt-col4">
#          <a href="https://spartangroup.io/index.html" rel="noopener noreferrer nofollow" target="_blank" title="https://spartangroup.io/index.html">
#           https://spartangroup.io/index.html
#          </a>
#          <a href="https://twitter.com/TheSpartanGroup" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/TheSpartanGroup">
#           https://twitter.com/TheSpartanGroup
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/the-spartan-group">
#           <div class="pcount" data-funid="840">
#            172
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="407" data-fund_slug="alameda-research">
#         <div class="hpt-col1">
#          10
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/alameda-research">
#           <img alt="Alameda Research" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Alameda-Research-logo.png"/>
#          </a>
#          <p class="mob-only">
#           Alameda Research
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Alameda Research
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.alameda-research.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.alameda-research.com/">
#           https://www.alameda-research.com/
#          </a>
#          <a href="https://twitter.com/AlamedaResearch" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/AlamedaResearch">
#           https://twitter.com/AlamedaResearch
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/alameda-research">
#           <div class="pcount" data-funid="407">
#            165
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="562" data-fund_slug="dragonfly-capital">
#         <div class="hpt-col1">
#          11
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/dragonfly-capital">
#           <img alt="Dragonfly Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Dragonfly-Capital-1.png"/>
#          </a>
#          <p class="mob-only">
#           Dragonfly Capital
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Dragonfly Capital
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.dragonfly.xyz/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.dragonfly.xyz/">
#           https://www.dragonfly.xyz/
#          </a>
#          <a href="https://twitter.com/dragonfly_xyz" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/dragonfly_xyz">
#           https://twitter.com/dragonfly_xyz
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/dragonfly-capital">
#           <div class="pcount" data-funid="562">
#            162
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="743" data-fund_slug="okx-blockdream-ventures">
#         <div class="hpt-col1">
#          12
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/okx-blockdream-ventures">
#           <img alt="OKX Ventures (ex OKEx Blockdream Ventures)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/OKX-Ventures.png"/>
#          </a>
#          <p class="mob-only">
#           OKX Ventures (ex OKEx Blockdream Ventures)
#          </p>
#         </div>
#         <div class="hpt-col3">
#          OKX Ventures (ex OKEx Blockdream Ventures)
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.okx.com/ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://www.okx.com/ventures">
#           https://www.okx.com/ventures
#          </a>
#          <a href="https://twitter.com/OKX_Ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/OKX_Ventures">
#           https://twitter.com/OKX_Ventures
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/okx-blockdream-ventures">
#           <div class="pcount" data-funid="743">
#            162
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="439" data-fund_slug="binance-labs-fund">
#         <div class="hpt-col1">
#          13
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/binance-labs-fund">
#           <img alt="Binance Labs Fund" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Binance-labs.png"/>
#          </a>
#          <p class="mob-only">
#           Binance Labs Fund
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Binance Labs Fund
#         </div>
#         <div class="hpt-col4">
#          <a href="https://labs.binance.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://labs.binance.com/">
#           https://labs.binance.com/
#          </a>
#          <a href="https://twitter.com/BinanceLabs" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/BinanceLabs">
#           https://twitter.com/BinanceLabs
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/binance-labs-fund">
#           <div class="pcount" data-funid="439">
#            144
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="415" data-fund_slug="au21-capital">
#         <div class="hpt-col1">
#          14
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/au21-capital">
#           <img alt="AU21 Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/au21-e1661167248779.png"/>
#          </a>
#          <p class="mob-only">
#           AU21 Capital
#          </p>
#         </div>
#         <div class="hpt-col3">
#          AU21 Capital
#         </div>
#         <div class="hpt-col4">
#          <a href="https://au21.capital/" rel="noopener noreferrer nofollow" target="_blank" title="https://au21.capital/">
#           https://au21.capital/
#          </a>
#          <a href="https://twitter.com/AU21Capital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/AU21Capital">
#           https://twitter.com/AU21Capital
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/au21-capital">
#           <div class="pcount" data-funid="415">
#            138
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="518" data-fund_slug="cms">
#         <div class="hpt-col1">
#          15
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/cms">
#           <img alt="CMS Holdings" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/Funds/CMS.png"/>
#          </a>
#          <p class="mob-only">
#           CMS Holdings
#          </p>
#         </div>
#         <div class="hpt-col3">
#          CMS Holdings
#         </div>
#         <div class="hpt-col4">
#          <a href="http://cmsholdings.io/" rel="noopener noreferrer nofollow" target="_blank" title="http://cmsholdings.io/">
#           http://cmsholdings.io/
#          </a>
#          <a href="https://twitter.com/cmsholdings" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/cmsholdings">
#           https://twitter.com/cmsholdings
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/cms">
#           <div class="pcount" data-funid="518">
#            138
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="827" data-fund_slug="shima-capital">
#         <div class="hpt-col1">
#          16
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/shima-capital">
#           <img alt="Shima Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/shima2.png"/>
#          </a>
#          <p class="mob-only">
#           Shima Capital
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Shima Capital
#         </div>
#         <div class="hpt-col4">
#          <a href="https://shima.capital/" rel="noopener noreferrer nofollow" target="_blank" title="https://shima.capital/">
#           https://shima.capital/
#          </a>
#          <a href="https://twitter.com/shimacapital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/shimacapital">
#           https://twitter.com/shimacapital
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/shima-capital">
#           <div class="pcount" data-funid="827">
#            135
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="359" data-fund_slug="hashed">
#         <div class="hpt-col1">
#          17
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/hashed">
#           <img alt="Hashed" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Hashed.webp"/>
#          </a>
#          <p class="mob-only">
#           Hashed
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Hashed
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.hashed.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.hashed.com/">
#           https://www.hashed.com/
#          </a>
#          <a href="https://twitter.com/hashed_official" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/hashed_official">
#           https://twitter.com/hashed_official
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/hashed">
#           <div class="pcount" data-funid="359">
#            134
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="674" data-fund_slug="gsr-markets-ltd">
#         <div class="hpt-col1">
#          18
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/gsr-markets-ltd">
#           <img alt="GSR Markets LTD" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/GSR-2.png"/>
#          </a>
#          <p class="mob-only">
#           GSR Markets LTD
#          </p>
#         </div>
#         <div class="hpt-col3">
#          GSR Markets LTD
#         </div>
#         <div class="hpt-col4">
#          <a href="https://www.gsr.io/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.gsr.io/">
#           https://www.gsr.io/
#          </a>
#          <a href="https://twitter.com/GSR_io" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/GSR_io">
#           https://twitter.com/GSR_io
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/gsr-markets-ltd">
#           <div class="pcount" data-funid="674">
#            131
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="813" data-fund_slug="polygon-ventures">
#         <div class="hpt-col1">
#          19
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/polygon-ventures">
#           <img alt="P2 Ventures (Polygon Ventures)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/P2-Ventures.png"/>
#          </a>
#          <p class="mob-only">
#           P2 Ventures (Polygon Ventures)
#          </p>
#         </div>
#         <div class="hpt-col3">
#          P2 Ventures (Polygon Ventures)
#         </div>
#         <div class="hpt-col4">
#          <a href="https://polygonventures.xyz/" rel="noopener noreferrer nofollow" target="_blank" title="https://polygonventures.xyz/">
#           https://polygonventures.xyz/
#          </a>
#          <a href="https://twitter.com/Polygonventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/Polygonventures">
#           https://twitter.com/Polygonventures
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/polygon-ventures">
#           <div class="pcount" data-funid="813">
#            125
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="hp-table-row hpt-data" data-fund_id="738" data-fund_slug="morningstar-ventures">
#         <div class="hpt-col1">
#          20
#         </div>
#         <div class="hpt-col2">
#          <a class="aprojects nochevron" href="/funds/morningstar-ventures">
#           <img alt="Morningstar Ventures" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Morningstar-Ventures-1.png"/>
#          </a>
#          <p class="mob-only">
#           Morningstar Ventures
#          </p>
#         </div>
#         <div class="hpt-col3">
#          Morningstar Ventures
#         </div>
#         <div class="hpt-col4">
#          <a href="https://morningstar.ventures/" rel="noopener noreferrer nofollow" target="_blank" title="https://morningstar.ventures/">
#           https://morningstar.ventures/
#          </a>
#          <a href="https://twitter.com/Morningstar_vc" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/Morningstar_vc">
#           https://twitter.com/Morningstar_vc
#          </a>
#         </div>
#         <div class="hpt-col5 flexwrap">
#          <a class="aprojects" href="/funds/morningstar-ventures">
#           <div class="pcount" data-funid="738">
#            125
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="pagination">
#        <span aria-current="page" class="page-numbers current">
#         1
#        </span>
#        <a class="page-numbers" href="https://crypto-fundraising.info/investors/page/2/">
#         2
#        </a>
#        <a class="page-numbers" href="https://crypto-fundraising.info/investors/page/3/">
#         3
#        </a>
#        <span class="page-numbers dots">
#         …
#        </span>
#        <a class="page-numbers" href="https://crypto-fundraising.info/investors/page/357/">
#         357
#        </a>
#        <a class="page-numbers" href="https://crypto-fundraising.info/investors/page/358/">
#         358
#        </a>
#        <a class="next page-numbers" href="https://crypto-fundraising.info/investors/page/2/">
#        </a>
#       </div>
#      </div>
#      <div class="sidebar">
#       <div class="ad-wrapper">
#       </div>
#       <div class="ad-wrapper">
#       </div>
#      </div>
#     </div>
#     <div class="wrapper">
#      <div class="central-banner dt-only">
#      </div>
#      <div class="central-banner mobile">
#      </div>
#     </div>
#    </main>
#    <footer class="site-footer">
#     <div class="wrapper">
#      <div class="footercol col1">
#       <img alt="logo" class="logo-full" height="32" src="https://crypto-fundraising.info/wp-content/themes/ico/img/cf-logo.svg" width="206"/>
#      </div>
#      <div class="footer-menuwrap">
#       <div class="footercol col2">
#       </div>
#       <div class="footercol col2">
#        <div class="menu-footer-2-container">
#         <ul class="menu" id="footer-2">
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-59755" id="menu-item-59755">
#           <a href="https://crypto-fundraising.info/api/">
#            API
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6557" id="menu-item-6557">
#           <a href="https://crypto-fundraising.info/advertising/">
#            Advertising
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-wpautoterms_page menu-item-7594" id="menu-item-7594">
#           <a href="https://crypto-fundraising.info/wpautoterms/privacy-policy/">
#            Privacy Policy
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="footercol col2">
#        <div class="menu-footer-3-container">
#         <ul class="menu" id="footer-3">
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-30" id="menu-item-30">
#           <a href="https://twitter.com/Crypto_Dealflow">
#            Twitter
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-31" id="menu-item-31">
#           <a href="https://t.me/crypto_fundraising">
#            TG channel
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="wrapper">
#      <div class="site-info">
#       © 2024  CRYPTO fundraising. All Rights Reserved.
#      </div>
#     </div>
#    </footer>
#    <script id="libs-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/libs.js?ver=1.0.0">
#    </script>
#    <script id="jui-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/jquery-ui.js?ver=1.0.0">
#    </script>
#    <script id="moment-custom-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/moment.min.js?ver=1.0.0">
#    </script>
#    <script id="daterange-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/daterangepicker.min.js?ver=1.0.0">
#    </script>
#    <script id="jquery-mask-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/jquery.mask.min.js?ver=1.0.0">
#    </script>
#    <script id="app-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/app.js?ver=1.0.0">
#    </script>
#    <script id="salesdata-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/intertables.js?ver=1.0.0">
#    </script>
#    <script id="funds-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/funds.js?ver=1.0.0">
#    </script>
#    <script id="jq-zip-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/jszip.min.js?ver=1.0">
#    </script>
#    <script id="jq-filesaver-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/FileSaver.min.js?ver=1.0">
#    </script>
#    <script id="custom-zip-download-js" src="https://crypto-fundraising.info/wp-content/themes/ico/js/custom-zip-download.js?ver=1.0">
#    </script>
#    <script id="wp-featherlight-js" src="https://crypto-fundraising.info/wp-content/plugins/wp-featherlight/js/wpFeatherlight.pkgd.min.js?ver=1.3.4">
#    </script>
#   </div>
#  </body>
# </html>
# <!-- Cache served by breeze CACHE - Last modified: Sat, 10 Aug 2024 04:13:47 GMT -->

# %% [markdown]
# - Identifying Relevant HTML Elements for Scraping

# %%
soup.find_all('div', class_='htop')
# Out:
# [<div class="hpt-col1 htop"> <span>#</span></div>,
#  <div class="hpt-col2 htop wsort"><div class="sorter" data-sort="default" data-sortby="pname"></div> <span>Fund name</span></div>,
#  <div class="hpt-col3 htop"></div>,
#  <div class="hpt-col4 htop"> <span>Website</span></div>,
#  <div class="hpt-col5 htop wsort"><div class="sorter" data-sort="default" data-sortby="pcount"></div> <span>Invested projects</span></div>]

# %%
soup.find_all('div', class_='htop', span_='')
# Out:
# [<div class="hpt-col1 htop"> <span>#</span></div>,
#  <div class="hpt-col2 htop wsort"><div class="sorter" data-sort="default" data-sortby="pname"></div> <span>Fund name</span></div>,
#  <div class="hpt-col3 htop"></div>,
#  <div class="hpt-col4 htop"> <span>Website</span></div>,
#  <div class="hpt-col5 htop wsort"><div class="sorter" data-sort="default" data-sortby="pcount"></div> <span>Invested projects</span></div>]

# %%
column = soup.find_all('div', class_='htop')

# %% [markdown]
# - Extracting data elements from html.

# %%
# Find all div elements with class 'htop'
column = soup.find_all('div', class_='htop')

if column:
    for div in column:
        spans = div.find_all('span')
        for span in spans:
            print(span.text)
else:
    print("No divs with class 'htop' found")
# Out:
# #
# Fund name
# Website
# Invested projects

# %%
data = []

# %% [markdown]
# - Creating a dataFrame to organize extracted data.

# %%
# Create a DataFrame
df = pd.DataFrame(data, columns=['#', 'Fund name', 'Website', 'Invested projects'])
df
# Out:
# Empty DataFrame
# Columns: [#, Fund name, Website, Invested projects]
# Index: []

# %%
 soup.find_all('div', class_='hpt-data')
# Out:
# [<div class="hp-table-row hpt-data" data-fund_id="249" data-fund_slug="coinbase-ventures"><div class="hpt-col1"> 01 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/coinbase-ventures"> <img alt="Coinbase Ventures" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/01/cb-ven.png"/> </a><p class="mob-only">Coinbase Ventures</p></div><div class="hpt-col3"> Coinbase Ventures</div><div class="hpt-col4"> <a href="https://www.coinbase.com/ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://www.coinbase.com/ventures"> https://www.coinbase.com/ventures </a> <a href="https://twitter.com/cbventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/cbventures"> https://twitter.com/cbventures </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/coinbase-ventures"><div class="pcount" data-funid="249"> 331</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="410" data-fund_slug="animoca-brands"><div class="hpt-col1"> 02 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/animoca-brands"> <img alt="Animoca Brands" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Animoca-Brands.png"/> </a><p class="mob-only">Animoca Brands</p></div><div class="hpt-col3"> Animoca Brands</div><div class="hpt-col4"> <a href="https://www.animocabrands.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.animocabrands.com/"> https://www.animocabrands.com/ </a> <a href="https://twitter.com/animocabrands" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/animocabrands"> https://twitter.com/animocabrands </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/animoca-brands"><div class="pcount" data-funid="410"> 263</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="557" data-fund_slug="digital-currency-group"><div class="hpt-col1"> 03 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/digital-currency-group"> <img alt="Digital Currency Group (DCG)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Digital-Currency-Group@3x-logo.png"/> </a><p class="mob-only">Digital Currency Group (DCG)</p></div><div class="hpt-col3"> Digital Currency Group (DCG)</div><div class="hpt-col4"> <a href="https://dcg.co/" rel="noopener noreferrer nofollow" target="_blank" title="https://dcg.co/"> https://dcg.co/ </a> <a href="https://twitter.com/DCGco" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/DCGco"> https://twitter.com/DCGco </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/digital-currency-group"><div class="pcount" data-funid="557"> 225</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="370" data-fund_slug="a16z-crypto"><div class="hpt-col1"> 04 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/a16z-crypto"> <img alt="Andreessen Horowitz (a16z crypto)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/a16zcrypto_Logo.png"/> </a><p class="mob-only">Andreessen Horowitz (a16z crypto)</p></div><div class="hpt-col3"> Andreessen Horowitz (a16z crypto)</div><div class="hpt-col4"> <a href="https://a16zcrypto.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://a16zcrypto.com/"> https://a16zcrypto.com/ </a> <a href="https://twitter.com/a16zcrypto" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/a16zcrypto"> https://twitter.com/a16zcrypto </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/a16z-crypto"><div class="pcount" data-funid="370"> 224</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="741" data-fund_slug="ngc-ventures"><div class="hpt-col1"> 05 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/ngc-ventures"> <img alt="NGC Ventures (NEO Global Capital)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/Funds/NGC-Ventures.png"/> </a><p class="mob-only">NGC Ventures (NEO Global Capital)</p></div><div class="hpt-col3"> NGC Ventures (NEO Global Capital)</div><div class="hpt-col4"> <a href="https://ngc.fund/" rel="noopener noreferrer nofollow" target="_blank" title="https://ngc.fund/"> https://ngc.fund/ </a> <a href="https://twitter.com/NGC_Ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/NGC_Ventures"> https://twitter.com/NGC_Ventures </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/ngc-ventures"><div class="pcount" data-funid="741"> 208</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="573" data-fund_slug="polychain-capital"><div class="hpt-col1"> 06 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/polychain-capital"> <img alt="Polychain Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/polychain.png"/> </a><p class="mob-only">Polychain Capital</p></div><div class="hpt-col3"> Polychain Capital</div><div class="hpt-col4"> <a href="https://polychain.capital/" rel="noopener noreferrer nofollow" target="_blank" title="https://polychain.capital/"> https://polychain.capital/ </a> <a href="https://twitter.com/polychain" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/polychain"> https://twitter.com/polychain </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/polychain-capital"><div class="pcount" data-funid="573"> 204</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="247" data-fund_slug="pantera-capital"><div class="hpt-col1"> 07 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/pantera-capital"> <img alt="Pantera Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/01/Pantera-capital.png"/> </a><p class="mob-only">Pantera Capital</p></div><div class="hpt-col3"> Pantera Capital</div><div class="hpt-col4"> <a href="https://panteracapital.com/firm/" rel="noopener noreferrer nofollow" target="_blank" title="https://panteracapital.com/firm/"> https://panteracapital.com/firm/ </a> <a href="https://twitter.com/PanteraCapital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/PanteraCapital"> https://twitter.com/PanteraCapital </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/pantera-capital"><div class="pcount" data-funid="247"> 189</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="568" data-fund_slug="hashkey-capital"><div class="hpt-col1"> 08 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/hashkey-capital"> <img alt="Hashkey Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/header-v3-logo-2.png"/> </a><p class="mob-only">Hashkey Capital</p></div><div class="hpt-col3"> Hashkey Capital</div><div class="hpt-col4"> <a href="https://capital.hashkey.com/en/" rel="noopener noreferrer nofollow" target="_blank" title="https://capital.hashkey.com/en/"> https://capital.hashkey.com/en/ </a> <a href="https://twitter.com/HashKey_Capital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/HashKey_Capital"> https://twitter.com/HashKey_Capital </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/hashkey-capital"><div class="pcount" data-funid="568"> 176</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="840" data-fund_slug="the-spartan-group"><div class="hpt-col1"> 09 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/the-spartan-group"> <img alt="The Spartan Group" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/600_478869280.png"/> </a><p class="mob-only">The Spartan Group</p></div><div class="hpt-col3"> The Spartan Group</div><div class="hpt-col4"> <a href="https://spartangroup.io/index.html" rel="noopener noreferrer nofollow" target="_blank" title="https://spartangroup.io/index.html"> https://spartangroup.io/index.html </a> <a href="https://twitter.com/TheSpartanGroup" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/TheSpartanGroup"> https://twitter.com/TheSpartanGroup </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/the-spartan-group"><div class="pcount" data-funid="840"> 172</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="407" data-fund_slug="alameda-research"><div class="hpt-col1"> 10 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/alameda-research"> <img alt="Alameda Research" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Alameda-Research-logo.png"/> </a><p class="mob-only">Alameda Research</p></div><div class="hpt-col3"> Alameda Research</div><div class="hpt-col4"> <a href="https://www.alameda-research.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.alameda-research.com/"> https://www.alameda-research.com/ </a> <a href="https://twitter.com/AlamedaResearch" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/AlamedaResearch"> https://twitter.com/AlamedaResearch </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/alameda-research"><div class="pcount" data-funid="407"> 165</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="562" data-fund_slug="dragonfly-capital"><div class="hpt-col1"> 11 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/dragonfly-capital"> <img alt="Dragonfly Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Dragonfly-Capital-1.png"/> </a><p class="mob-only">Dragonfly Capital</p></div><div class="hpt-col3"> Dragonfly Capital</div><div class="hpt-col4"> <a href="https://www.dragonfly.xyz/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.dragonfly.xyz/"> https://www.dragonfly.xyz/ </a> <a href="https://twitter.com/dragonfly_xyz" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/dragonfly_xyz"> https://twitter.com/dragonfly_xyz </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/dragonfly-capital"><div class="pcount" data-funid="562"> 162</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="743" data-fund_slug="okx-blockdream-ventures"><div class="hpt-col1"> 12 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/okx-blockdream-ventures"> <img alt="OKX Ventures (ex OKEx Blockdream Ventures)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/OKX-Ventures.png"/> </a><p class="mob-only">OKX Ventures (ex OKEx Blockdream Ventures)</p></div><div class="hpt-col3"> OKX Ventures (ex OKEx Blockdream Ventures)</div><div class="hpt-col4"> <a href="https://www.okx.com/ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://www.okx.com/ventures"> https://www.okx.com/ventures </a> <a href="https://twitter.com/OKX_Ventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/OKX_Ventures"> https://twitter.com/OKX_Ventures </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/okx-blockdream-ventures"><div class="pcount" data-funid="743"> 162</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="439" data-fund_slug="binance-labs-fund"><div class="hpt-col1"> 13 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/binance-labs-fund"> <img alt="Binance Labs Fund" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Binance-labs.png"/> </a><p class="mob-only">Binance Labs Fund</p></div><div class="hpt-col3"> Binance Labs Fund</div><div class="hpt-col4"> <a href="https://labs.binance.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://labs.binance.com/"> https://labs.binance.com/ </a> <a href="https://twitter.com/BinanceLabs" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/BinanceLabs"> https://twitter.com/BinanceLabs </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/binance-labs-fund"><div class="pcount" data-funid="439"> 144</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="415" data-fund_slug="au21-capital"><div class="hpt-col1"> 14 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/au21-capital"> <img alt="AU21 Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/au21-e1661167248779.png"/> </a><p class="mob-only">AU21 Capital</p></div><div class="hpt-col3"> AU21 Capital</div><div class="hpt-col4"> <a href="https://au21.capital/" rel="noopener noreferrer nofollow" target="_blank" title="https://au21.capital/"> https://au21.capital/ </a> <a href="https://twitter.com/AU21Capital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/AU21Capital"> https://twitter.com/AU21Capital </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/au21-capital"><div class="pcount" data-funid="415"> 138</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="518" data-fund_slug="cms"><div class="hpt-col1"> 15 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/cms"> <img alt="CMS Holdings" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/Funds/CMS.png"/> </a><p class="mob-only">CMS Holdings</p></div><div class="hpt-col3"> CMS Holdings</div><div class="hpt-col4"> <a href="http://cmsholdings.io/" rel="noopener noreferrer nofollow" target="_blank" title="http://cmsholdings.io/"> http://cmsholdings.io/ </a> <a href="https://twitter.com/cmsholdings" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/cmsholdings"> https://twitter.com/cmsholdings </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/cms"><div class="pcount" data-funid="518"> 138</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="827" data-fund_slug="shima-capital"><div class="hpt-col1"> 16 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/shima-capital"> <img alt="Shima Capital" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/shima2.png"/> </a><p class="mob-only">Shima Capital</p></div><div class="hpt-col3"> Shima Capital</div><div class="hpt-col4"> <a href="https://shima.capital/" rel="noopener noreferrer nofollow" target="_blank" title="https://shima.capital/"> https://shima.capital/ </a> <a href="https://twitter.com/shimacapital" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/shimacapital"> https://twitter.com/shimacapital </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/shima-capital"><div class="pcount" data-funid="827"> 135</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="359" data-fund_slug="hashed"><div class="hpt-col1"> 17 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/hashed"> <img alt="Hashed" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Hashed.webp"/> </a><p class="mob-only">Hashed</p></div><div class="hpt-col3"> Hashed</div><div class="hpt-col4"> <a href="https://www.hashed.com/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.hashed.com/"> https://www.hashed.com/ </a> <a href="https://twitter.com/hashed_official" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/hashed_official"> https://twitter.com/hashed_official </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/hashed"><div class="pcount" data-funid="359"> 134</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="674" data-fund_slug="gsr-markets-ltd"><div class="hpt-col1"> 18 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/gsr-markets-ltd"> <img alt="GSR Markets LTD" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/GSR-2.png"/> </a><p class="mob-only">GSR Markets LTD</p></div><div class="hpt-col3"> GSR Markets LTD</div><div class="hpt-col4"> <a href="https://www.gsr.io/" rel="noopener noreferrer nofollow" target="_blank" title="https://www.gsr.io/"> https://www.gsr.io/ </a> <a href="https://twitter.com/GSR_io" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/GSR_io"> https://twitter.com/GSR_io </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/gsr-markets-ltd"><div class="pcount" data-funid="674"> 131</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="813" data-fund_slug="polygon-ventures"><div class="hpt-col1"> 19 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/polygon-ventures"> <img alt="P2 Ventures (Polygon Ventures)" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/P2-Ventures.png"/> </a><p class="mob-only">P2 Ventures (Polygon Ventures)</p></div><div class="hpt-col3"> P2 Ventures (Polygon Ventures)</div><div class="hpt-col4"> <a href="https://polygonventures.xyz/" rel="noopener noreferrer nofollow" target="_blank" title="https://polygonventures.xyz/"> https://polygonventures.xyz/ </a> <a href="https://twitter.com/Polygonventures" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/Polygonventures"> https://twitter.com/Polygonventures </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/polygon-ventures"><div class="pcount" data-funid="813"> 125</div> </a></div></div>,
#  <div class="hp-table-row hpt-data" data-fund_id="738" data-fund_slug="morningstar-ventures"><div class="hpt-col1"> 20 </div><div class="hpt-col2"> <a class="aprojects nochevron" href="/funds/morningstar-ventures"> <img alt="Morningstar Ventures" class="fundlogoinvest" src="https://crypto-fundraising.info/wp-content/uploads/funds/2022/02/Morningstar-Ventures-1.png"/> </a><p class="mob-only">Morningstar Ventures</p></div><div class="hpt-col3"> Morningstar Ventures</div><div class="hpt-col4"> <a href="https://morningstar.ventures/" rel="noopener noreferrer nofollow" target="_blank" title="https://morningstar.ventures/"> https://morningstar.ventures/ </a> <a href="https://twitter.com/Morningstar_vc" rel="noopener noreferrer nofollow" target="_blank" title="https://twitter.com/Morningstar_vc"> https://twitter.com/Morningstar_vc </a></div><div class="hpt-col5 flexwrap"> <a class="aprojects" href="/funds/morningstar-ventures"><div class="pcount" data-funid="738"> 125</div> </a></div></div>]

# %%
rows = soup.find_all('div', class_='hpt-data')

# %% [markdown]
# - Looping through all pages to scrape data.

# %%
# Base URL 
base_url = 'https://crypto-fundraising.info/investors/?page='

# List 
all_data = []

# Number of pages 
total_pages = 358

# Loop through all pages
for page_number in range(1, total_pages + 1):
    # URL for the current page
    url = f"{base_url}{page_number}"
    
    #GET request
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the page content
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extract the data 
        rows = soup.find_all('div', class_='hpt-data')  
        
        # Loop through the rows and extract
        for row in rows:
            # Extract these details 
            rank = row.find('div', class_='hpt-col1').text.strip()
            name = row.find('div', class_='hpt-col3').text.strip()
            website = row.find('div', class_='hpt-col4').a['href'].strip()
            twitter = row.find('div', class_='hpt-col4').find_all('a')[1]['href'].strip()
            investments = row.find('div', class_='pcount').text.strip()
            
            # Store the data
            all_data.append({
                'Rank': rank,
                'Name': name,
                'Website': website,
                'Twitter': twitter,
                'Investments': investments
            })
        
        # Print the progress
        print(f"Successfully scraped page {page_number} of {total_pages}")
        
        # 
        time.sleep(1)  
    else:
        print(f"Failed to retrieve page {page_number}")
# Out:
# Successfully scraped page 1 of 358
# Successfully scraped page 2 of 358
# Successfully scraped page 3 of 358
# Successfully scraped page 4 of 358
# Successfully scraped page 5 of 358
# Successfully scraped page 6 of 358
# Successfully scraped page 7 of 358
# Successfully scraped page 8 of 358
# Successfully scraped page 9 of 358
# Successfully scraped page 10 of 358
# Successfully scraped page 11 of 358
# Successfully scraped page 12 of 358
# Successfully scraped page 13 of 358
# Successfully scraped page 14 of 358
# Successfully scraped page 15 of 358
# Successfully scraped page 16 of 358
# Successfully scraped page 17 of 358
# Successfully scraped page 18 of 358
# Successfully scraped page 19 of 358
# Successfully scraped page 20 of 358
# Successfully scraped page 21 of 358
# Successfully scraped page 22 of 358
# Successfully scraped page 23 of 358
# Successfully scraped page 24 of 358
# Successfully scraped page 25 of 358
# Successfully scraped page 26 of 358
# Successfully scraped page 27 of 358
# Successfully scraped page 28 of 358
# Successfully scraped page 29 of 358
# Successfully scraped page 30 of 358
# Successfully scraped page 31 of 358
# Successfully scraped page 32 of 358
# Successfully scraped page 33 of 358
# Successfully scraped page 34 of 358
# Successfully scraped page 35 of 358
# Successfully scraped page 36 of 358
# Successfully scraped page 37 of 358
# Successfully scraped page 38 of 358
# Successfully scraped page 39 of 358
# Successfully scraped page 40 of 358
# Successfully scraped page 41 of 358
# Successfully scraped page 42 of 358
# Successfully scraped page 43 of 358
# Successfully scraped page 44 of 358
# Successfully scraped page 45 of 358
# Successfully scraped page 46 of 358
# Successfully scraped page 47 of 358
# Successfully scraped page 48 of 358
# Successfully scraped page 49 of 358
# Successfully scraped page 50 of 358
# Successfully scraped page 51 of 358
# Successfully scraped page 52 of 358
# Successfully scraped page 53 of 358
# Successfully scraped page 54 of 358
# Successfully scraped page 55 of 358
# Successfully scraped page 56 of 358
# Successfully scraped page 57 of 358
# Successfully scraped page 58 of 358
# Successfully scraped page 59 of 358
# Successfully scraped page 60 of 358
# Successfully scraped page 61 of 358
# Successfully scraped page 62 of 358
# Successfully scraped page 63 of 358
# Successfully scraped page 64 of 358
# Successfully scraped page 65 of 358
# Successfully scraped page 66 of 358
# Successfully scraped page 67 of 358
# Successfully scraped page 68 of 358
# Successfully scraped page 69 of 358
# Successfully scraped page 70 of 358
# Successfully scraped page 71 of 358
# Successfully scraped page 72 of 358
# Successfully scraped page 73 of 358
# Successfully scraped page 74 of 358
# Successfully scraped page 75 of 358
# Successfully scraped page 76 of 358
# Successfully scraped page 77 of 358
# Successfully scraped page 78 of 358
# Successfully scraped page 79 of 358
# Successfully scraped page 80 of 358
# Successfully scraped page 81 of 358
# Successfully scraped page 82 of 358
# Successfully scraped page 83 of 358
# Successfully scraped page 84 of 358
# Successfully scraped page 85 of 358
# Successfully scraped page 86 of 358
# Successfully scraped page 87 of 358
# Successfully scraped page 88 of 358
# Successfully scraped page 89 of 358
# Successfully scraped page 90 of 358
# Successfully scraped page 91 of 358
# Successfully scraped page 92 of 358
# Successfully scraped page 93 of 358
# Successfully scraped page 94 of 358
# Successfully scraped page 95 of 358
# Successfully scraped page 96 of 358
# Successfully scraped page 97 of 358
# Successfully scraped page 98 of 358
# Successfully scraped page 99 of 358
# Successfully scraped page 100 of 358
# Successfully scraped page 101 of 358
# Successfully scraped page 102 of 358
# Successfully scraped page 103 of 358
# Successfully scraped page 104 of 358
# Successfully scraped page 105 of 358
# Successfully scraped page 106 of 358
# Successfully scraped page 107 of 358
# Successfully scraped page 108 of 358
# Successfully scraped page 109 of 358
# Successfully scraped page 110 of 358
# Successfully scraped page 111 of 358
# Successfully scraped page 112 of 358
# Successfully scraped page 113 of 358
# Successfully scraped page 114 of 358
# Successfully scraped page 115 of 358
# Successfully scraped page 116 of 358
# Successfully scraped page 117 of 358
# Successfully scraped page 118 of 358
# Successfully scraped page 119 of 358
# Successfully scraped page 120 of 358
# Successfully scraped page 121 of 358
# Successfully scraped page 122 of 358
# Successfully scraped page 123 of 358
# Successfully scraped page 124 of 358
# Successfully scraped page 125 of 358
# Successfully scraped page 126 of 358
# Successfully scraped page 127 of 358
# Successfully scraped page 128 of 358
# Successfully scraped page 129 of 358
# Successfully scraped page 130 of 358
# Successfully scraped page 131 of 358
# Successfully scraped page 132 of 358
# Successfully scraped page 133 of 358
# Successfully scraped page 134 of 358
# Successfully scraped page 135 of 358
# Successfully scraped page 136 of 358
# Successfully scraped page 137 of 358
# Successfully scraped page 138 of 358
# Successfully scraped page 139 of 358
# Successfully scraped page 140 of 358
# Successfully scraped page 141 of 358
# Successfully scraped page 142 of 358
# Successfully scraped page 143 of 358
# Successfully scraped page 144 of 358
# Successfully scraped page 145 of 358
# Successfully scraped page 146 of 358
# Successfully scraped page 147 of 358
# Successfully scraped page 148 of 358
# Successfully scraped page 149 of 358
# Successfully scraped page 150 of 358
# Successfully scraped page 151 of 358
# Successfully scraped page 152 of 358
# Successfully scraped page 153 of 358
# Successfully scraped page 154 of 358
# Successfully scraped page 155 of 358
# Successfully scraped page 156 of 358
# Successfully scraped page 157 of 358
# Successfully scraped page 158 of 358
# Successfully scraped page 159 of 358
# Successfully scraped page 160 of 358
# Successfully scraped page 161 of 358
# Successfully scraped page 162 of 358
# Successfully scraped page 163 of 358
# Successfully scraped page 164 of 358
# Successfully scraped page 165 of 358
# Successfully scraped page 166 of 358
# Successfully scraped page 167 of 358
# Successfully scraped page 168 of 358
# Successfully scraped page 169 of 358
# Successfully scraped page 170 of 358
# Successfully scraped page 171 of 358
# Successfully scraped page 172 of 358
# Successfully scraped page 173 of 358
# Successfully scraped page 174 of 358
# Successfully scraped page 175 of 358
# Successfully scraped page 176 of 358
# Successfully scraped page 177 of 358
# Successfully scraped page 178 of 358
# Successfully scraped page 179 of 358
# Successfully scraped page 180 of 358
# Successfully scraped page 181 of 358
# Successfully scraped page 182 of 358
# Successfully scraped page 183 of 358
# Successfully scraped page 184 of 358
# Successfully scraped page 185 of 358
# Successfully scraped page 186 of 358
# Successfully scraped page 187 of 358
# Successfully scraped page 188 of 358
# Successfully scraped page 189 of 358
# Successfully scraped page 190 of 358
# Successfully scraped page 191 of 358
# Successfully scraped page 192 of 358
# Successfully scraped page 193 of 358
# Successfully scraped page 194 of 358
# Successfully scraped page 195 of 358
# Successfully scraped page 196 of 358
# Successfully scraped page 197 of 358
# Successfully scraped page 198 of 358
# Successfully scraped page 199 of 358
# Successfully scraped page 200 of 358
# Successfully scraped page 201 of 358
# Successfully scraped page 202 of 358
# Successfully scraped page 203 of 358
# Successfully scraped page 204 of 358
# Successfully scraped page 205 of 358
# Successfully scraped page 206 of 358
# Successfully scraped page 207 of 358
# Successfully scraped page 208 of 358
# Successfully scraped page 209 of 358
# Successfully scraped page 210 of 358
# Successfully scraped page 211 of 358
# Successfully scraped page 212 of 358
# Successfully scraped page 213 of 358
# Successfully scraped page 214 of 358
# Successfully scraped page 215 of 358
# Successfully scraped page 216 of 358
# Successfully scraped page 217 of 358
# Successfully scraped page 218 of 358
# Successfully scraped page 219 of 358
# Successfully scraped page 220 of 358
# Successfully scraped page 221 of 358
# Successfully scraped page 222 of 358
# Successfully scraped page 223 of 358
# Successfully scraped page 224 of 358
# Successfully scraped page 225 of 358
# Successfully scraped page 226 of 358
# Successfully scraped page 227 of 358
# Successfully scraped page 228 of 358
# Successfully scraped page 229 of 358
# Successfully scraped page 230 of 358
# Successfully scraped page 231 of 358
# Successfully scraped page 232 of 358
# Successfully scraped page 233 of 358
# Successfully scraped page 234 of 358
# Successfully scraped page 235 of 358
# Successfully scraped page 236 of 358
# Successfully scraped page 237 of 358
# Successfully scraped page 238 of 358
# Successfully scraped page 239 of 358
# Successfully scraped page 240 of 358
# Successfully scraped page 241 of 358
# Successfully scraped page 242 of 358
# Successfully scraped page 243 of 358
# Successfully scraped page 244 of 358
# Successfully scraped page 245 of 358
# Successfully scraped page 246 of 358
# Successfully scraped page 247 of 358
# Successfully scraped page 248 of 358
# Successfully scraped page 249 of 358
# Successfully scraped page 250 of 358
# Successfully scraped page 251 of 358
# Successfully scraped page 252 of 358
# Successfully scraped page 253 of 358
# Successfully scraped page 254 of 358
# Successfully scraped page 255 of 358
# Successfully scraped page 256 of 358
# Successfully scraped page 257 of 358
# Successfully scraped page 258 of 358
# Successfully scraped page 259 of 358
# Successfully scraped page 260 of 358
# Successfully scraped page 261 of 358
# Successfully scraped page 262 of 358
# Successfully scraped page 263 of 358
# Successfully scraped page 264 of 358
# Successfully scraped page 265 of 358
# Successfully scraped page 266 of 358
# Successfully scraped page 267 of 358
# Successfully scraped page 268 of 358
# Successfully scraped page 269 of 358
# Successfully scraped page 270 of 358
# Successfully scraped page 271 of 358
# Successfully scraped page 272 of 358
# Successfully scraped page 273 of 358
# Successfully scraped page 274 of 358
# Successfully scraped page 275 of 358
# Successfully scraped page 276 of 358
# Successfully scraped page 277 of 358
# Successfully scraped page 278 of 358
# Successfully scraped page 279 of 358
# Successfully scraped page 280 of 358
# Successfully scraped page 281 of 358
# Successfully scraped page 282 of 358
# Successfully scraped page 283 of 358
# Successfully scraped page 284 of 358
# Successfully scraped page 285 of 358
# Successfully scraped page 286 of 358
# Failed to retrieve page 287
# Failed to retrieve page 288
# Successfully scraped page 289 of 358
# Successfully scraped page 290 of 358
# Successfully scraped page 291 of 358
# Successfully scraped page 292 of 358
# Successfully scraped page 293 of 358
# Successfully scraped page 294 of 358
# Successfully scraped page 295 of 358
# Successfully scraped page 296 of 358
# Successfully scraped page 297 of 358
# Successfully scraped page 298 of 358
# Successfully scraped page 299 of 358
# Successfully scraped page 300 of 358
# Successfully scraped page 301 of 358
# Successfully scraped page 302 of 358
# Successfully scraped page 303 of 358
# Successfully scraped page 304 of 358
# Successfully scraped page 305 of 358
# Successfully scraped page 306 of 358
# Successfully scraped page 307 of 358
# Successfully scraped page 308 of 358
# Successfully scraped page 309 of 358
# Successfully scraped page 310 of 358
# Successfully scraped page 311 of 358
# Successfully scraped page 312 of 358
# Successfully scraped page 313 of 358
# Successfully scraped page 314 of 358
# Successfully scraped page 315 of 358
# Successfully scraped page 316 of 358
# Successfully scraped page 317 of 358
# Successfully scraped page 318 of 358
# Successfully scraped page 319 of 358
# Successfully scraped page 320 of 358
# Successfully scraped page 321 of 358
# Successfully scraped page 322 of 358
# Successfully scraped page 323 of 358
# Successfully scraped page 324 of 358
# Successfully scraped page 325 of 358
# Failed to retrieve page 326
# Successfully scraped page 327 of 358
# Successfully scraped page 328 of 358
# Successfully scraped page 329 of 358
# Successfully scraped page 330 of 358
# Successfully scraped page 331 of 358
# Successfully scraped page 332 of 358
# Failed to retrieve page 333
# Successfully scraped page 334 of 358
# Successfully scraped page 335 of 358
# Successfully scraped page 336 of 358
# Successfully scraped page 337 of 358
# Successfully scraped page 338 of 358
# Successfully scraped page 339 of 358
# Successfully scraped page 340 of 358
# Successfully scraped page 341 of 358
# Failed to retrieve page 342
# Successfully scraped page 343 of 358
# Successfully scraped page 344 of 358
# Successfully scraped page 345 of 358
# Successfully scraped page 346 of 358
# Successfully scraped page 347 of 358
# Failed to retrieve page 348
# Successfully scraped page 349 of 358
# Successfully scraped page 350 of 358
# Successfully scraped page 351 of 358
# Successfully scraped page 352 of 358
# Successfully scraped page 353 of 358
# Successfully scraped page 354 of 358
# Successfully scraped page 355 of 358
# Successfully scraped page 356 of 358
# Successfully scraped page 357 of 358
# Failed to retrieve page 358

# %% [markdown]
# - Saving and exporting data.

# %%
# Convert the list of data into a DataFrame
df = pd.DataFrame(all_data)

# Save the DataFrame to a CSV file
df.to_csv('scraped_data.csv', index=False)

# Save the DataFrame to an Excel file
df.to_excel('scraped_data.xlsx', index=False)
